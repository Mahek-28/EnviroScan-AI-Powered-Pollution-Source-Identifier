# %% [markdown]
# Enviroscan AI-Powered Source Identifier using Geospatical Analysis for India Country

# %% [markdown]
# Data Extraction code for Pysical features

# %% [markdown]
# Install Required libraries`

# %%
pip install osmnx geopandas pandas openpyxl shapely
# Out:
# Requirement already satisfied: osmnx in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (2.0.7)
# Requirement already satisfied: geopandas in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (1.1.1)
# Requirement already satisfied: pandas in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: shapely in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (2.1.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from osmnx) (3.4.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from osmnx) (2.2.4)
# Requirement already satisfied: requests>=2.27 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from osmnx) (2.32.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (24.2)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: certifi in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->osmnx) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mahek rana\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27->osmnx) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# OpenStreetMap Feature Extraction for Air Quality Analysis
# This script extracts nearby physical features (roads, industrial zones, dumps, agricultural fields)
# from OpenStreetMap using OSMnx library in small batches with error handling

import pandas as pd
import numpy as np
import osmnx as ox
import geopandas as gpd
from shapely.geometry import Point, box
import warnings
import time
from typing import Dict, List, Tuple
import sys

warnings.filterwarnings('ignore')

# ============================================================================
# CONFIGURATION
# ============================================================================

BATCH_SIZE = 5
SEARCH_RADIUS = 1000  # meters = 1KM
OUTPUT_FILE = "Air_Quality_with_OSM_Features.xlsx"
INPUT_FILE = "Air Quality Dataset 2021-2023.xlsx"

# ============================================================================
# FEATURE EXTRACTION FUNCTIONS
# ============================================================================

def extract_roads(lat: float, lon: float, radius: int) -> Dict:
    """Extract road features from OSM"""
    try:
        roads = ox.features_from_point(
            (lat, lon),
            tags={'highway': True},
            dist=radius
        )
        
        if len(roads) > 0:
            road_names = [roads.index.get_level_values(0).unique()[i] 
                         for i in range(min(5, len(roads.index.get_level_values(0).unique())))]
            return {
                'count': len(roads),
                'examples': ', '.join(str(r)[:40] for r in road_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_industrial_zones(lat: float, lon: float, radius: int) -> Dict:
    """Extract industrial facilities from OSM"""
    try:
        tags = {'industrial': True, 'landuse': 'industrial'}
        industrial = ox.features_from_point((lat, lon), tags=tags, dist=radius)
        
        if len(industrial) > 0:
            ind_names = industrial.index.get_level_values(0).unique()[:5]
            return {
                'count': len(industrial),
                'examples': ', '.join(str(i)[:35] for i in ind_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_dump_sites(lat: float, lon: float, radius: int) -> Dict:
    """Extract waste management and dump sites from OSM"""
    try:
        tags = {'waste': True}
        dumps = ox.features_from_point((lat, lon), tags=tags, dist=radius)
        
        if len(dumps) > 0:
            dump_names = dumps.index.get_level_values(0).unique()[:5]
            return {
                'count': len(dumps),
                'examples': ', '.join(str(d)[:35] for d in dump_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_agricultural_fields(lat: float, lon: float, radius: int) -> Dict:
    """Extract agricultural areas from OSM"""
    try:
        tags = {'landuse': ['farmland', 'farm', 'agricultural', 'grass', 'meadow']}
        agriculture = ox.features_from_point((lat, lon), tags=tags, dist=radius)
        
        if len(agriculture) > 0:
            agr_names = agriculture.index.get_level_values(0).unique()[:5]
            return {
                'count': len(agriculture),
                'examples': ', '.join(str(a)[:35] for a in agr_names),
                'status': 'success'
            }
        return {'count': 0, 'examples': '', 'status': 'success'}
    except Exception as e:
        return {'count': 0, 'examples': f"Error: {str(e)[:30]}", 'status': 'failed'}

def extract_all_features(lat: float, lon: float, radius: int) -> Dict:
    """Extract all features for a location"""
    features = {
        'roads': extract_roads(lat, lon, radius),
        'industrial': extract_industrial_zones(lat, lon, radius),
        'dumps': extract_dump_sites(lat, lon, radius),
        'agriculture': extract_agricultural_fields(lat, lon, radius)
    }
    return features

# ============================================================================
# MAIN PROCESSING
# ============================================================================

def main():
    print(f"\n{'='*80}")
    print("OSM FEATURE EXTRACTION FOR AIR QUALITY ANALYSIS")
    print(f"{'='*80}\n")
    
    # Load dataset
    print(f"Loading dataset from {INPUT_FILE}...")
    df = pd.read_excel(INPUT_FILE, sheet_name=0)
    print(f"✓ Loaded {len(df)} records\n")
    
    # Get unique locations
    unique_locations = df[['Latitude', 'Longitude', 'Location', 'State / Union Territory',
                           'City / town / village']].drop_duplicates(
                           subset=['Latitude', 'Longitude']).reset_index(drop=True)
    
    print(f"Unique locations to process: {len(unique_locations)}")
    print(f"Processing parameters:")
    print(f"  - Batch size: {BATCH_SIZE}")
    print(f"  - Search radius: {SEARCH_RADIUS}m")
    print(f"\n{'='*80}\n")
    
    # Initialize results
    features_data = []
    total_batches = (len(unique_locations) - 1) // BATCH_SIZE + 1
    
    # Process in batches
    for batch_num in range(0, len(unique_locations), BATCH_SIZE):
        batch = unique_locations.iloc[batch_num:batch_num + BATCH_SIZE]
        batch_idx = (batch_num // BATCH_SIZE) + 1
        
        print(f"Batch {batch_idx}/{total_batches}:")
        print(f"Processing locations {batch_num + 1} to {min(batch_num + BATCH_SIZE, len(unique_locations))}\n")
        
        for idx, row in batch.iterrows():
            lat = row['Latitude']
            lon = row['Longitude']
            location_name = row['Location']
            city = row['City / town / village']
            state = row['State / Union Territory']
            
            try:
                # Extract features
                print(f"  Querying {city}, {state} ({lat:.4f}, {lon:.4f})...", end='', flush=True)
                features = extract_all_features(lat, lon, SEARCH_RADIUS)
                
                # Compile record
                record = {
                    'Location': location_name,
                    'City': city,
                    'State': state,
                    'Latitude': lat,
                    'Longitude': lon,
                    'Roads_count': features['roads']['count'],
                    'Roads_examples': features['roads']['examples'],
                    'Industrial_zones_count': features['industrial']['count'],
                    'Industrial_examples': features['industrial']['examples'],
                    'Dump_sites_count': features['dumps']['count'],
                    'Dump_examples': features['dumps']['examples'],
                    'Agricultural_fields_count': features['agriculture']['count'],
                    'Agricultural_examples': features['agriculture']['examples'],
                    'Query_status': 'Success'
                }
                
                features_data.append(record)
                
                print(f" ✓ Roads:{features['roads']['count']} | "
                      f"Industrial:{features['industrial']['count']} | "
                      f"Dumps:{features['dumps']['count']} | "
                      f"Agriculture:{features['agriculture']['count']}")
                
            except Exception as e:
                print(f" ✗ Error: {str(e)[:50]}")
                record = {
                    'Location': location_name,
                    'City': city,
                    'State': state,
                    'Latitude': lat,
                    'Longitude': lon,
                    'Roads_count': 0,
                    'Roads_examples': '',
                    'Industrial_zones_count': 0,
                    'Industrial_examples': '',
                    'Dump_sites_count': 0,
                    'Dump_examples': '',
                    'Agricultural_fields_count': 0,
                    'Agricultural_examples': '',
                    'Query_status': f'Failed: {str(e)[:40]}'
                }
                features_data.append(record)
            
            # Small delay between queries to avoid rate limiting
            time.sleep(0.5)
        
        print(f"\nBatch completed. Waiting before next batch...\n")
        time.sleep(2)
    
    # Create features dataframe
    features_df = pd.DataFrame(features_data)
    
    # Print summary statistics
    print(f"\n{'='*80}")
    print("EXTRACTION SUMMARY")
    print(f"{'='*80}\n")
    
    print(f"Total locations processed: {len(features_df)}")
    successful = (features_df['Query_status'] == 'Success').sum()
    print(f"Successful queries: {successful}/{len(features_df)}")
    
    print(f"\n{'Feature Statistics':^80}")
    print(f"{'-'*80}")
    print(f"{'Feature':<20} {'Total':<12} {'Mean':<12} {'Max':<12}")
    print(f"{'-'*80}")
    print(f"{'Roads':<20} {features_df['Roads_count'].sum():<12.0f} "
          f"{features_df['Roads_count'].mean():<12.1f} {features_df['Roads_count'].max():<12.0f}")
    print(f"{'Industrial':<20} {features_df['Industrial_zones_count'].sum():<12.0f} "
          f"{features_df['Industrial_zones_count'].mean():<12.1f} "
          f"{features_df['Industrial_zones_count'].max():<12.0f}")
    print(f"{'Dump Sites':<20} {features_df['Dump_sites_count'].sum():<12.0f} "
          f"{features_df['Dump_sites_count'].mean():<12.1f} {features_df['Dump_sites_count'].max():<12.0f}")
    print(f"{'Agriculture':<20} {features_df['Agricultural_fields_count'].sum():<12.0f} "
          f"{features_df['Agricultural_fields_count'].mean():<12.1f} "
          f"{features_df['Agricultural_fields_count'].max():<12.0f}")
    print(f"{'-'*80}\n")
    
    # Merge with original data
    print("Merging extracted features with original air quality data...")
    
    # Merge on latitude and longitude
    merged_df = df.merge(
        features_df[['Latitude', 'Longitude', 'Roads_count', 'Industrial_zones_count',
                     'Dump_sites_count', 'Agricultural_fields_count', 'Query_status']],
        on=['Latitude', 'Longitude'],
        how='left'
    )
    
    # Fill NaN values for unmatched records (should be minimal)
    merged_df['Roads_count'].fillna(0, inplace=True)
    merged_df['Industrial_zones_count'].fillna(0, inplace=True)
    merged_df['Dump_sites_count'].fillna(0, inplace=True)
    merged_df['Agricultural_fields_count'].fillna(0, inplace=True)
    merged_df['Query_status'].fillna('Not processed', inplace=True)
    
    # Create additional derived features
    merged_df['Urban_density_score'] = (merged_df['Roads_count'] / merged_df['Roads_count'].max()).round(2)
    merged_df['Industrial_presence'] = (merged_df['Industrial_zones_count'] > 0).astype(int)
    merged_df['Pollution_source_risk'] = (
        (merged_df['Industrial_zones_count'] * 0.4 + 
         merged_df['Dump_sites_count'] * 0.3 + 
         merged_df['Roads_count'] * 0.3) / 100
    ).round(2)
    merged_df['Green_area_ratio'] = (
        merged_df['Agricultural_fields_count'] / 
        (merged_df['Roads_count'] + merged_df['Agricultural_fields_count'])
    ).round(2)
    
    # Save to Excel
    print(f"\nSaving merged data to {OUTPUT_FILE}...")
    with pd.ExcelWriter(OUTPUT_FILE, engine='openpyxl') as writer:
        merged_df.to_excel(writer, sheet_name='All Data', index=False)
        features_df.to_excel(writer, sheet_name='OSM Features', index=False)
        
        # Summary statistics sheet
        summary_stats = pd.DataFrame({
            'Metric': ['Total Records', 'Unique Locations', 'Successful Queries',
                      'Mean Roads', 'Mean Industrial', 'Mean Dumps', 'Mean Agriculture',
                      'Max Roads', 'Max Industrial', 'Max Dumps', 'Max Agriculture'],
            'Value': [len(merged_df), len(features_df), successful,
                     f"{features_df['Roads_count'].mean():.1f}",
                     f"{features_df['Industrial_zones_count'].mean():.1f}",
                     f"{features_df['Dump_sites_count'].mean():.1f}",
                     f"{features_df['Agricultural_fields_count'].mean():.1f}",
                     features_df['Roads_count'].max(),
                     features_df['Industrial_zones_count'].max(),
                     features_df['Dump_sites_count'].max(),
                     features_df['Agricultural_fields_count'].max()]
        })
        summary_stats.to_excel(writer, sheet_name='Summary', index=False)
    
    print(f"✓ Successfully saved to {OUTPUT_FILE}\n")
    
    # Display sample results
    print(f"{'Sample Results (First 15 locations):':^80}")
    print(merged_df[['City / town / village', 'State / Union Territory', 'Roads_count',
                     'Industrial_zones_count', 'Dump_sites_count', 'Agricultural_fields_count',
                     'Pollution_source_risk', 'Green_area_ratio']].head(15))
    
    print(f"\n{'='*80}")
    print("✓ Processing Complete!")
    print(f"{'='*80}\n")
    
    return merged_df, features_df

if __name__ == "__main__":
    merged_df, features_df = main()
# Out:
# ================================================================================
# OSM FEATURE EXTRACTION FOR AIR QUALITY ANALYSIS
# ================================================================================
#
# Loading dataset from Air Quality Dataset 2021-2023.xlsx...
# ✓ Loaded 1068 records
#
# Unique locations to process: 544
# Processing parameters:
#   - Batch size: 5
#   - Search radius: 1000m
#
# ================================================================================
#
# Batch 1/109:
# Processing locations 1 to 5
#
#   Querying Amaravati, Andhra Pradesh (16.4942, 80.5106)... ✓ Roads:84 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Anatapur, Andhra Pradesh (14.6824, 77.6017)... ✓ Roads:723 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Chittor, Andhra Pradesh (13.2162, 79.1051)... ✓ Roads:369 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Eluru, Andhra Pradesh (16.7104, 81.1154)... ✓ Roads:671 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Guntur, Andhra Pradesh (16.2915, 80.4542)... ✓ Roads:780 | Industrial:2 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 2/109:
# Processing locations 6 to 10
#
#   Querying Kadapa, Andhra Pradesh (14.4753, 78.8217)... ✓ Roads:588 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Kakinada, Andhra Pradesh (16.9437, 82.2351)... ✓ Roads:419 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Kurnool, Andhra Pradesh (15.8309, 78.0425)... ✓ Roads:679 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Nellore, Andhra Pradesh (14.4494, 79.9874)... ✓ Roads:697 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Ongole, Andhra Pradesh (15.5059, 80.0499)... ✓ Roads:536 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 3/109:
# Processing locations 11 to 15
#
#   Querying Rajahmundry, Andhra Pradesh (17.0050, 81.7805)... ✓ Roads:841 | Industrial:1 | Dumps:0 | Agriculture:2
#   Querying Srikakulam, Andhra Pradesh (18.2949, 83.8939)... ✓ Roads:468 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Tirupati, Andhra Pradesh (13.6316, 79.4232)... ✓ Roads:737 | Industrial:1 | Dumps:0 | Agriculture:3
#   Querying Vijayawada, Andhra Pradesh (16.5115, 80.6160)... ✓ Roads:576 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Visakhapatnam, Andhra Pradesh (17.6936, 83.2921)... ✓ Roads:253 | Industrial:9 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 4/109:
# Processing locations 16 to 20
#
#   Querying Vizianagaram, Andhra Pradesh (18.1141, 83.4114)... ✓ Roads:577 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Itanagar, Arunachal Pradesh (27.0980, 93.6237)... ✓ Roads:208 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Naharlagun, Arunachal Pradesh (27.1309, 93.7097)... ✓ Roads:78 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bongaigaon, Assam (26.4800, 90.5580)... ✓ Roads:289 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Daranga, Assam (26.7851, 91.5145)... ✓ Roads:38 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 5/109:
# Processing locations 21 to 25
#
#   Querying Dibrugarh, Assam (27.4845, 94.9019)... ✓ Roads:245 | Industrial:0 | Dumps:0 | Agriculture:4
#   Querying Golaghat, Assam (26.5108, 93.9744)... ✓ Roads:149 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Guwahati, Assam (26.1806, 91.7539)... ✓ Roads:500 | Industrial:0 | Dumps:0 | Agriculture:6
#   Querying Magherita, Assam (27.2864, 95.6702)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nagaon, Assam (26.3314, 92.7525)... ✓ Roads:9 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 6/109:
# Processing locations 26 to 30
#
#   Querying Nalbari, Assam (26.3534, 91.3984)... ✓ Roads:24 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying North Lakhimpur, Assam (27.2544, 94.1120)... ✓ Roads:50 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Silcher, Assam (24.8333, 92.7789)... ✓ Roads:247 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Sivasagar, Assam (26.9835, 94.6394)... ✓ Roads:203 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tezpur, Assam (26.6170, 92.7650)... ✓ Roads:28 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 7/109:
# Processing locations 31 to 35
#
#   Querying Tinsukia, Assam (27.4880, 95.3602)... ✓ Roads:391 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Gaya, Bihar (24.6794, 85.0116)... ✓ Roads:104 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Hajipur, Bihar (25.6906, 85.2090)... ✓ Roads:519 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Muzaffarpur, Bihar (26.1483, 85.3316)... ✓ Roads:108 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Patna, Bihar (25.6093, 85.1235)... ✓ Roads:778 | Industrial:0 | Dumps:0 | Agriculture:14
#
# Batch completed. Waiting before next batch...
#
# Batch 8/109:
# Processing locations 36 to 40
#
#   Querying Chandigarh, Chandigarh (UT) (30.7333, 76.7794)... ✓ Roads:739 | Industrial:2 | Dumps:2 | Agriculture:2
#   Querying Bilaspur, Chattisgarh (22.1638, 82.1366)... ✓ Roads:85 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Durg-Bhillainagar, Chattisgarh (21.1888, 81.2849)... ✓ Roads:479 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Korba, Chattisgarh (22.5198, 82.6350)... ✓ Roads:21 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Raigarh, Chattisgarh (22.2362, 83.3530)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 9/109:
# Processing locations 41 to 45
#
#   Querying Raipur, Chattisgarh (21.2381, 81.6337)... ✓ Roads:497 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Daman, Dadara & Nagar Haveli and Daman & Diu (UT) (20.4283, 72.8397)... ✓ Roads:108 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Delhi, Delhi (UT) (28.6139, 77.2090)... ✓ Roads:940 | Industrial:0 | Dumps:2 | Agriculture:73
#   Querying Amona, Goa (15.5354, 73.9838)... ✓ Roads:115 | Industrial:1 | Dumps:0 | Agriculture:4
#   Querying Assanora, Goa (15.5891, 73.8103)... ✓ Roads:861 | Industrial:15 | Dumps:1 | Agriculture:15
#
# Batch completed. Waiting before next batch...
#
# Batch 10/109:
# Processing locations 46 to 50
#
#   Querying Bicholim, Goa (15.5558, 73.9773)... ✓ Roads:89 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Codli, Goa (15.3567, 74.1238)... ✓ Roads:25 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Cuncolim, Goa (15.1801, 73.9979)... ✓ Roads:95 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Honda, Goa (15.5431, 74.0586)... ✓ Roads:150 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Kundaim, Goa (15.4597, 73.9613)... ✓ Roads:104 | Industrial:2 | Dumps:0 | Agriculture:19
#
# Batch completed. Waiting before next batch...
#
# Batch 11/109:
# Processing locations 51 to 55
#
#   Querying Mapusa, Goa (15.5909, 73.8102)... ✓ Roads:900 | Industrial:17 | Dumps:1 | Agriculture:15
#   Querying Margao, Goa (15.2729, 73.9583)... ✓ Roads:428 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Panaji, Goa (15.4990, 73.8282)... ✓ Roads:679 | Industrial:5 | Dumps:0 | Agriculture:10
#   Querying Ponda, Goa (15.3979, 74.0080)... ✓ Roads:257 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Sanguem, Goa (15.2283, 74.1513)... ✓ Roads:120 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 12/109:
# Processing locations 56 to 60
#
#   Querying Tilamol, Goa (15.2806, 74.0943)... ✓ Roads:26 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Tuem, Goa (15.6666, 73.7957)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Usgao-Pale, Goa (15.4892, 74.0703)... ✓ Roads:67 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Vasco, Goa (15.3984, 73.8129)... ✓ Roads:244 | Industrial:4 | Dumps:0 | Agriculture:1
#   Querying Ahmedabad, Gujarat (23.0215, 72.5801)... ✓ Roads:958 | Industrial:2 | Dumps:0 | Agriculture:3
#
# Batch completed. Waiting before next batch...
#
# Batch 13/109:
# Processing locations 61 to 65
#
#   Querying Ankleshwar, Gujarat (21.6293, 72.9945)... ✓ Roads:212 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Gandhinagar, Gujarat (23.2233, 72.6492)... ✓ Roads:424 | Industrial:0 | Dumps:0 | Agriculture:12
#   Querying Jamnagar, Gujarat (22.4732, 70.0552)... ✓ Roads:492 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Nandesari, Gujarat (22.4178, 73.0949)... ✓ Roads:192 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Navarangpur, Gujarat (19.2310, 82.5482)... ✓ Roads:15 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 14/109:
# Processing locations 66 to 70
#
#   Querying Rajkot, Gujarat (22.3053, 70.8028)... ✓ Roads:822 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Surat, Gujarat (21.2095, 72.8317)... ✓ Roads:827 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Saraspur, Gujara (23.0475, 72.6036)... ✓ Roads:525 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Vadodara, Gujarat (22.2973, 73.1943)... ✓ Roads:477 | Industrial:0 | Dumps:0 | Agriculture:4
#   Querying Vapi, Gujarat (20.3735, 72.9084)... ✓ Roads:202 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 15/109:
# Processing locations 71 to 75
#
#   Querying Vatva, Gujarat (22.9590, 72.6298)... ✓ Roads:912 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Ambala, Haryana (30.3844, 76.7704)... ✓ Roads:717 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bahadurgarh, Haryana (28.6610, 76.8347)... ✓ Roads:31 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ballabgarh, Haryana (28.2941, 77.3592)... ✓ Roads:73 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhiwani, Haryana (28.7932, 76.1391)... ✓ Roads:582 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 16/109:
# Processing locations 76 to 80
#
#   Querying Charkhi Dadri, Haryana (28.5920, 76.2720)... ✓ Roads:81 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dharuhera, Haryana (28.2055, 76.7953)... ✓ Roads:292 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Faridabad, Haryana (28.4031, 77.3106)... ✓ Roads:563 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Fatehabad, Haryana (29.5359, 75.5753)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:5
#   Querying Gurgaon, Haryana (28.4646, 77.0299)... ✓ Roads:1012 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 17/109:
# Processing locations 81 to 85
#
#   Querying Hissar, Haryana (29.8292, 76.4723)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jind, Haryana (29.3152, 76.3141)... ✓ Roads:611 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kaithal, Haryana (29.7997, 76.3990)... ✓ Roads:660 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Karnal, Haryana (29.7256, 76.9107)... ✓ Roads:33 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kurukshetra, Haryana (29.9694, 76.8483)... ✓ Roads:682 | Industrial:3 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 18/109:
# Processing locations 86 to 90
#
#   Querying Mandikhera, Haryana (27.8971, 76.9922)... ✓ Roads:9 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Manesar, Haryana (28.3247, 76.9264)... ✓ Roads:61 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Narnaul, Haryana (28.0438, 76.1062)... ✓ Roads:190 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Palwal, Haryana (28.0599, 77.3223)... ✓ Roads:23 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Panchukula Urban Estate, Haryana (30.6942, 76.8606)... ✓ Roads:654 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 19/109:
# Processing locations 91 to 95
#
#   Querying Panipat, Haryana (29.3913, 76.9772)... ✓ Roads:778 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rohtak, Haryana (28.9011, 76.5802)... ✓ Roads:816 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sirsa, Haryana (29.6063, 74.9037)... ✓ Roads:15 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sonepat, Haryana (28.9920, 77.0343)... ✓ Roads:834 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Yamuna Nagar, Haryana (30.1389, 77.3011)... ✓ Roads:693 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 20/109:
# Processing locations 96 to 100
#
#   Querying Baddi, Himachal Pradesh (30.9763, 76.7674)... ✓ Roads:36 | Industrial:12 | Dumps:0 | Agriculture:0
#   Querying Damtal, Himachal Pradesh (32.2539, 75.6722)... ✓ Roads:136 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dharamshala, Himachal Pradesh (32.2143, 76.3197)... ✓ Roads:406 | Industrial:1 | Dumps:0 | Agriculture:10
#   Querying Kala Amb, Himachal Pradesh (32.0131, 76.6688)... ✓ Roads:10 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Manali, Himachal Pradesh (32.2455, 77.1873)... ✓ Roads:316 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 21/109:
# Processing locations 101 to 105
#
#   Querying Nalagarh, Himachal Pradesh (31.1060, 76.6567)... ✓ Roads:2 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Parwanoo, Himachal Pradesh (30.8379, 76.9602)... ✓ Roads:109 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Poanta Sahib, Himachal Pradesh (30.4366, 77.6247)... ✓ Roads:227 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Shimla, Himachal Pradesh (31.1042, 77.1710)... ✓ Roads:157 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sunder Nagar, Himachal Pradesh (31.5163, 76.8840)... ✓ Roads:27 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 22/109:
# Processing locations 106 to 110
#
#   Querying Una, Himachal Pradesh (31.5835, 76.2351)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Jammu, Jammu & Kashmir (UT) (33.7782, 76.5762)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Pulwama (K), Jammu & Kashmir (UT) (33.8747, 74.8998)... ✓ Roads:80 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Srinagar (K), Jammu & Kashmir (UT) (34.0837, 74.7973)... ✓ Roads:616 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Barajamda, Jharkhand (22.1641, 85.4078)... ✓ Roads:30 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 23/109:
# Processing locations 111 to 115
#
#   Querying Dhanbad, Jharkhand (23.7953, 86.4310)... ✓ Roads:394 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Jamshedpur, Jharkhand (22.8015, 86.2030)... ✓ Roads:391 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Jharia, Jharkhand (23.7408, 86.4146)... ✓ Roads:268 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jorapokhar, Jharkhand (23.7167, 86.4110)... ✓ Roads:234 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ranchi, Jharkhand (23.3701, 85.3250)... ✓ Roads:523 | Industrial:1 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 24/109:
# Processing locations 116 to 120
#
#   Querying Saraikela, Jharkhand (22.7464, 85.9169)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sindri, Jharkhand (23.6752, 86.4896)... ✓ Roads:163 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Bagalkote, Karnataka (16.2904, 75.5916)... ✓ Roads:54 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bangalore, Karnataka (12.9768, 77.5901)... ✓ Roads:2459 | Industrial:2 | Dumps:2 | Agriculture:45
#   Querying Belgaum, Karnataka (15.8573, 74.5069)... ✓ Roads:329 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 25/109:
# Processing locations 121 to 125
#
#   Querying Bidar, Karnataka (18.0207, 77.2487)... ✓ Roads:10 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bijapur / Vijayapura, Karnataka (16.8333, 75.7176)... ✓ Roads:507 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Chamarajanagar, Karnataka (11.9544, 77.1069)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chikkaballapur, Karnataka (13.0994, 77.3887)... ✓ Roads:613 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chikkamagaluru, Karnataka (13.4059, 75.6388)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 26/109:
# Processing locations 126 to 130
#
#   Querying Chitradurga, Karnataka (14.3049, 76.5297)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Devanagere, Karnataka (14.4644, 75.9218)... ✓ Roads:466 | Industrial:6 | Dumps:0 | Agriculture:0
#   Querying Gadag, Karnataka (15.4167, 75.6816)... ✓ Roads:38 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gulbarga / Kalaburgi, Karnataka (17.3297, 76.8343)... ✓ Roads:557 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Hassan, Karnataka (13.0302, 76.1745)... ✓ Roads:39 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 27/109:
# Processing locations 131 to 135
#
#   Querying Hubli-Dharwad, Karnataka (15.3428, 75.1695)... ✓ Roads:208 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Kolar, Karnataka (13.1805, 78.2669)... ✓ Roads:9 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Koppal, Karnataka (15.5748, 76.3118)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Madikeri, Karnataka (12.4215, 75.7388)... ✓ Roads:250 | Industrial:1 | Dumps:0 | Agriculture:3
#   Querying Mandya, Karnataka (12.6369, 76.7275)... ✓ Roads:43 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 28/109:
# Processing locations 136 to 140
#
#   Querying Mangalore, Karnataka (12.8698, 74.8430)... ✓ Roads:465 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mysore, Karnataka (12.3052, 76.6554)... ✓ Roads:839 | Industrial:0 | Dumps:0 | Agriculture:13
#   Querying Raichur, Karnataka (16.0547, 76.9004)... ✓ Roads:11 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ramanagara, Karnataka (12.7200, 77.3184)... ✓ Roads:11 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Shimaga / Shivamogga, Karnataka (13.9299, 75.5681)... ✓ Roads:679 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 29/109:
# Processing locations 141 to 145
#
#   Querying Tumkuru, Karnataka (13.3422, 77.1010)... ✓ Roads:591 | Industrial:1 | Dumps:0 | Agriculture:2
#   Querying Udupi, Karnataka (13.5270, 74.8732)... ✓ Roads:60 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Yadgir, Karnataka (16.5744, 76.9254)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Alappuzha, Kerala (9.5007, 76.4124)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Eloor, Kerala (10.0670, 76.2989)... ✓ Roads:275 | Industrial:4 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 30/109:
# Processing locations 146 to 150
#
#   Querying Ernakulam, Kerala (9.9837, 76.2740)... ✓ Roads:395 | Industrial:3 | Dumps:1 | Agriculture:1
#   Querying Kannur, Kerala (11.8764, 75.3738)... ✓ Roads:493 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Kochi, Kerala (9.9679, 76.2444)... ✓ Roads:475 | Industrial:3 | Dumps:0 | Agriculture:1
#   Querying Kollam, Kerala (8.8871, 76.5907)... ✓ Roads:741 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Kottayam, Kerala (9.6287, 76.6455)... ✓ Roads:27 | Industrial:0 | Dumps:0 | Agriculture:3
#
# Batch completed. Waiting before next batch...
#
# Batch 31/109:
# Processing locations 151 to 155
#
#   Querying Kozhikode, Kerala (11.2451, 75.7755)... ✓ Roads:352 | Industrial:2 | Dumps:0 | Agriculture:1
#   Querying Mallappuram, Kerala (11.0730, 76.0740)... ✓ Roads:123 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Palakkad, Kerala (10.7874, 76.4742)... ✓ Roads:67 | Industrial:0 | Dumps:0 | Agriculture:9
#   Querying Pathanamthitta, Kerala (9.2781, 76.9737)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Thiruvanantapuram, Kerala (8.5441, 76.9366)... ✓ Roads:605 | Industrial:2 | Dumps:0 | Agriculture:4
#
# Batch completed. Waiting before next batch...
#
# Batch 32/109:
# Processing locations 156 to 160
#
#   Querying Thrissur, Kerala (10.5270, 76.2146)... ✓ Roads:672 | Industrial:0 | Dumps:0 | Agriculture:18
#   Querying Wayanad, Kerala (11.7151, 76.1271)... ✓ Roads:37 | Industrial:0 | Dumps:0 | Agriculture:33
#   Querying Amlai, Madhya Pradesh (23.1733, 81.5917)... ✓ Roads:54 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhopal, Madhya Pradesh (23.2585, 77.4020)... ✓ Roads:488 | Industrial:0 | Dumps:0 | Agriculture:6
#   Querying Chindwara, Madhya Pradesh (22.0004, 78.8972)... ✓ Roads:29 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 33/109:
# Processing locations 161 to 165
#
#   Querying Damoh, Madhya Pradesh (23.7981, 79.5419)... ✓ Roads:20 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dewas, Madhya Pradesh (22.8057, 76.2940)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gwalior, Madhya Pradesh (26.2037, 78.1574)... ✓ Roads:741 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Indore, Madhya Pradesh (22.7204, 75.8682)... ✓ Roads:638 | Industrial:3 | Dumps:0 | Agriculture:10
#   Querying Jabalpur, Madhya Pradesh (23.1702, 79.9325)... ✓ Roads:378 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 34/109:
# Processing locations 166 to 170
#
#   Querying Katni, Madhya Pradesh (23.7176, 80.2610)... ✓ Roads:1 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Maihar, Madhya Pradesh (24.2604, 80.7593)... ✓ Roads:124 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mandideep, Madhya Pradesh (23.0938, 77.5114)... ✓ Roads:417 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Nagda, Madhya Pradesh (23.4579, 75.4191)... ✓ Roads:303 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Pithampur, Madhya Pradesh (22.6106, 75.6790)... ✓ Roads:88 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 35/109:
# Processing locations 171 to 175
#
#   Querying Ratlam, Madhya Pradesh (23.5022, 74.9552)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rewa, Madhya Pradesh (24.7561, 81.3811)... ✓ Roads:1 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sagar, Madhya Pradesh (23.8083, 78.7583)... ✓ Roads:307 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Satna, Madhya Pradesh (24.6954, 80.7770)... ✓ Roads:12 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Singrauli, Madhya Pradesh (24.2431, 82.3828)... ✓ Roads:10 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 36/109:
# Processing locations 176 to 180
#
#   Querying Ujjain, Madhya Pradesh (23.1885, 75.7717)... ✓ Roads:497 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Akola, Maharashtra (20.7618, 77.1921)... ✓ Roads:76 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ambernath, Maharashtra (19.2016, 73.2005)... ✓ Roads:310 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Amravati, Maharashtra (21.1545, 77.6443)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Aurangabad, Maharashtra (19.8773, 75.3390)... ✓ Roads:848 | Industrial:2 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 37/109:
# Processing locations 181 to 185
#
#   Querying Badlapur, Maharashtra (19.1666, 73.2389)... ✓ Roads:487 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Bhiwandi, Maharashtra (19.3026, 73.0588)... ✓ Roads:445 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Chandrapur, Maharashtra (20.0968, 79.5045)... ✓ Roads:8 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dombivali / Kalyan, Maharashtra (19.2569, 73.1329)... ✓ Roads:415 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Jalgaon, Maharashtra (20.8429, 75.5261)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 38/109:
# Processing locations 186 to 190
#
#   Querying Jalna, Maharashtra (19.9188, 75.8709)... ✓ Roads:17 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kolhapur, Maharashtra (16.7028, 74.2405)... ✓ Roads:585 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Latur, Maharashtra (18.3553, 76.7549)... ✓ Roads:35 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Mumbai, Maharashtra (19.0550, 72.8692)... ✓ Roads:587 | Industrial:14 | Dumps:0 | Agriculture:6
#   Querying Nagpur, Maharashtra (21.1498, 79.0821)... ✓ Roads:599 | Industrial:1 | Dumps:0 | Agriculture:2
#
# Batch completed. Waiting before next batch...
#
# Batch 39/109:
# Processing locations 191 to 195
#
#   Querying Nanded, Maharashtra (19.0940, 77.4832)... ✓ Roads:28 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nashik, Maharashtra (20.0112, 73.7902)... ✓ Roads:488 | Industrial:0 | Dumps:0 | Agriculture:6
#   Querying Navi Mumbai, Maharashtra (19.0308, 73.0199)... ✓ Roads:836 | Industrial:3 | Dumps:0 | Agriculture:9
#   Querying Pimpri-Chinchwad, Maharashtra (18.6279, 73.8010)... ✓ Roads:817 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Pune, Maharashtra (18.5214, 73.8545)... ✓ Roads:1349 | Industrial:0 | Dumps:0 | Agriculture:10
#
# Batch completed. Waiting before next batch...
#
# Batch 40/109:
# Processing locations 196 to 200
#
#   Querying Roha, Maharashtra (18.4466, 73.1239)... ✓ Roads:48 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Sangli, Maharashtra (17.1727, 74.5868)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Solapur, Maharashtra (17.8499, 75.2763)... ✓ Roads:8 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Thane, Maharashtra (19.1943, 72.9702)... ✓ Roads:895 | Industrial:2 | Dumps:0 | Agriculture:6
#   Querying Ulhas Nagar, Maharashtra (19.0642, 72.8848)... ✓ Roads:653 | Industrial:5 | Dumps:0 | Agriculture:2
#
# Batch completed. Waiting before next batch...
#
# Batch 41/109:
# Processing locations 201 to 205
#
#   Querying Vasai virar, Maharashtra (19.4210, 72.8197)... ✓ Roads:454 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Imphal, Manipur (24.7991, 93.9364)... ✓ Roads:339 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Byraihat, Meghalaya (25.9045, 91.8695)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dawki, Meghalaya (25.1856, 92.0216)... ✓ Roads:44 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Khlihriat, Meghalaya (25.3570, 92.3534)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 42/109:
# Processing locations 206 to 210
#
#   Querying Nongstoin, Meghalaya (25.5726, 91.2541)... ✓ Roads:1 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Shillong, Meghalaya (25.5760, 91.8828)... ✓ Roads:427 | Industrial:0 | Dumps:0 | Agriculture:12
#   Querying Tura, Meghalaya (25.5126, 90.2172)... ✓ Roads:23 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Umaim, Meghalaya (25.6710, 91.8991)... ✓ Roads:65 | Industrial:1 | Dumps:0 | Agriculture:6
#   Querying Aizwal, Mizoram (23.8389, 92.6243)... ✓ Roads:23 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 43/109:
# Processing locations 211 to 215
#
#   Querying Champhai, Mizoram (23.6317, 93.3493)... ✓ Roads:7 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Khatla, Mizoram (23.7191, 92.7142)... ✓ Roads:218 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kolasib, Mizoram (24.2313, 92.6766)... ✓ Roads:57 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Lawngtlai, Mizoram (22.3913, 92.7397)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Lunglei, Mizoram (22.9520, 92.6339)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 44/109:
# Processing locations 216 to 220
#
#   Querying Lengpui, Mizoram (23.8407, 92.6211)... ✓ Roads:18 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mamit, Mizoram (23.7564, 92.4515)... ✓ Roads:7 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Saiha, Mizoram (22.4880, 92.9813)... ✓ Roads:181 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Serchhip, Mizoram (23.3053, 92.8455)... ✓ Roads:35 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dimapur, Nagaland (25.9041, 93.7178)... ✓ Roads:346 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 45/109:
# Processing locations 221 to 225
#
#   Querying Kohima, Nagaland (25.6619, 94.1019)... ✓ Roads:214 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Angul, Odisha (21.1025, 84.9537)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Balasore, Odisha (21.5006, 86.9199)... ✓ Roads:195 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Berhampur, Odisha (21.4931, 86.6327)... ✓ Roads:4 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhubaneshwar, Odisha (20.2603, 85.8395)... ✓ Roads:667 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 46/109:
# Processing locations 226 to 230
#
#   Querying Bonaigarh, Odisha (21.7474, 84.3569)... ✓ Roads:118 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Brajrajnagar, Odisha (21.8499, 83.9255)... ✓ Roads:37 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Cuttack, Odisha (20.4686, 85.8792)... ✓ Roads:401 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jharsuguda, Odisha (21.8019, 83.9714)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kalinga Nagar, Odisha (20.2680, 85.7623)... ✓ Roads:407 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 47/109:
# Processing locations 231 to 235
#
#   Querying Konark, Odisha (19.9074, 86.1420)... ✓ Roads:29 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Paradeep, Odisha (20.2797, 86.6123)... ✓ Roads:37 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Puri, Odisha (19.8076, 85.8253)... ✓ Roads:357 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rajgangpur, Odisha (22.1861, 84.5835)... ✓ Roads:25 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Rayagada, Odisha (19.4427, 83.5873)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 48/109:
# Processing locations 236 to 240
#
#   Querying Rourkela, Odisha (22.2309, 84.8679)... ✓ Roads:237 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Sambalpur, Odisha (21.5571, 84.1529)... ✓ Roads:25 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Talcher, Odisha (20.9322, 85.2006)... ✓ Roads:12 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Karaikal, Pondicherry (UT) (10.9167, 79.8333)... ✓ Roads:272 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Pondicherry, Pondicherry (UT) (11.9416, 79.8083)... ✓ Roads:1108 | Industrial:3 | Dumps:0 | Agriculture:7
#
# Batch completed. Waiting before next batch...
#
# Batch 49/109:
# Processing locations 241 to 245
#
#   Querying Aligarh (Jagraon), Punjab (30.7994, 75.4945)... ✓ Roads:69 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Amritsar, Punjab (31.6340, 74.8723)... ✓ Roads:616 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Aspal Khurd (Tapa), Punjab (30.4078, 75.6212)... ✓ Roads:63 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bara Pind (Goraya), Punjab (31.1150, 75.8134)... ✓ Roads:134 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Batala, Punjab (31.8193, 75.2000)... ✓ Roads:533 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 50/109:
# Processing locations 246 to 250
#
#   Querying Bhatinda, Punjab (30.2068, 74.9464)... ✓ Roads:470 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Binjon (Garshankar), Punjab (30.5683, 74.9704)... ✓ Roads:71 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bishanpura (Payal), Punjab (30.3097, 75.8893)... ✓ Roads:69 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Changal (Sangrur), Punjab (30.2855, 75.7927)... ✓ Roads:11 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chowkimann (Jagraon), Punjab (30.7802, 75.9984)... ✓ Roads:34 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 51/109:
# Processing locations 251 to 255
#
#   Querying Dera Baba Nanak, Punjab (32.0318, 75.0285)... ✓ Roads:140 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Dera Bassi, Punjab (30.5882, 76.8439)... ✓ Roads:558 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Fatehpur (Samana), Punjab (30.1810, 76.2291)... ✓ Roads:15 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Gobindgarh Mandi Gobindgarh, Punjab (30.6693, 76.2975)... ✓ Roads:419 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Guru Ki Dhab (Kotkapura), Punjab (30.5413, 74.8190)... ✓ Roads:37 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 52/109:
# Processing locations 256 to 260
#
#   Querying Jaito Sarja (Batala), Punjab (31.7467, 75.1974)... ✓ Roads:91 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jalandhar, Punjab (31.2922, 75.5679)... ✓ Roads:598 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Khanna, Punjab (30.7006, 76.2221)... ✓ Roads:770 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kharaori (Sirhind), Punjab (30.2512, 75.7748)... ✓ Roads:8 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kotladoom (Ajnala), Punjab (30.2793, 75.8409)... ✓ Roads:20 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 53/109:
# Processing locations 261 to 265
#
#   Querying Lakho ke Behram (Ferozpur), Punjab (30.4520, 74.9655)... ✓ Roads:4 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ludhiana, Punjab (30.9090, 75.8516)... ✓ Roads:654 | Industrial:1 | Dumps:0 | Agriculture:1
#   Querying Mrar Kalan (Muktsar), Punjab (30.4825, 75.8073)... ✓ Roads:41 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mukandpur (Nawashahar), Punjab (31.1591, 76.0341)... ✓ Roads:22 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mureedke (Batala), Punjab (31.5167, 74.2500)... ✓ Roads:279 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 54/109:
# Processing locations 266 to 270
#
#   Querying Naudhrani (Malerkotla), Punjab (30.4024, 75.6542)... ✓ Roads:84 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Naya Nangal, Punjab (31.3799, 76.3600)... ✓ Roads:243 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Patiala, Punjab (30.2093, 76.3397)... ✓ Roads:44 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Peer Mohammad (Jalalabad), Punjab (30.4769, 74.7752)... ✓ Roads:4 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Poohli (Bhatinda), Punjab (30.2946, 75.0831)... ✓ Roads:19 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 55/109:
# Processing locations 271 to 275
#
#   Querying Qila Bharian (Sangrur), Punjab (30.4582, 75.6189)... ✓ Roads:51 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rakhra (Patiala), Punjab (30.3730, 76.2573)... ✓ Roads:62 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rohila (Samrala), Punjab (30.4384, 75.5852)... ✓ Roads:30 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rupnagar, Punjab (31.0917, 76.5290)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Subanpur (Dhilwan), Punjab (30.3305, 75.6577)... ✓ Roads:28 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 56/109:
# Processing locations 276 to 280
#
#   Querying Tirathpur (Amritsar I), Punjab (30.4227, 75.6129)... ✓ Roads:91 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ajmer, Rajasthan (26.4691, 74.6390)... ✓ Roads:630 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Alwar, Rajasthan (27.4140, 76.6170)... ✓ Roads:118 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bharatpur, Rajasthan (27.0247, 77.2920)... ✓ Roads:1 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhiwadi, Rajasthan (28.2039, 76.8374)... ✓ Roads:308 | Industrial:2 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 57/109:
# Processing locations 281 to 285
#
#   Querying Chittorgargh, Rajasthan (24.8890, 74.6260)... ✓ Roads:510 | Industrial:4 | Dumps:0 | Agriculture:0
#   Querying Jaipur, Rajasthan (26.9155, 75.8190)... ✓ Roads:555 | Industrial:0 | Dumps:0 | Agriculture:9
#   Querying Jodhpur, Rajasthan (26.2968, 73.0351)... ✓ Roads:899 | Industrial:0 | Dumps:0 | Agriculture:4
#   Querying Kota, Rajasthan (25.1737, 75.8574)... ✓ Roads:610 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Pali, Rajasthan (25.4552, 73.4194)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 58/109:
# Processing locations 286 to 290
#
#   Querying Udaipur, Rajasthan (24.5787, 73.6863)... ✓ Roads:467 | Industrial:0 | Dumps:0 | Agriculture:6
#   Querying Chungthang, Sikkim (27.8133, 88.5200)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gangtok, Sikkim (27.3290, 88.6123)... ✓ Roads:240 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mangan, Sikkim (27.7503, 88.5212)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Namchi, Sikkim (27.3031, 88.3786)... ✓ Roads:18 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 59/109:
# Processing locations 291 to 295
#
#   Querying Pelling, Sikkim (27.3004, 88.2357)... ✓ Roads:35 | Industrial:0 | Dumps:0 | Agriculture:4
#   Querying Rangpo, Sikkim (27.1744, 88.5303)... ✓ Roads:20 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Ravangla, Sikkim (27.3051, 88.3645)... ✓ Roads:146 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Singtam, Sikkim (27.2320, 88.4971)... ✓ Roads:20 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chennai, Tamilnadu (13.0837, 80.2702)... ✓ Roads:943 | Industrial:2 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 60/109:
# Processing locations 296 to 300
#
#   Querying Coimbatore, Tamilnadu (11.0018, 76.9628)... ✓ Roads:592 | Industrial:1 | Dumps:0 | Agriculture:6
#   Querying Cuddalore, Tamilnadu (11.5202, 79.3396)... ✓ Roads:259 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Dharmapuri, Tamilnadu (12.1456, 78.1132)... ✓ Roads:13 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gummidipoondi, Tamilnadu (13.4309, 80.0821)... ✓ Roads:5 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Madurai, Tamilnadu (9.9261, 78.1141)... ✓ Roads:669 | Industrial:2 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 61/109:
# Processing locations 301 to 305
#
#   Querying Mettur, Tamilnadu (11.7928, 77.8649)... ✓ Roads:30 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nagarcoil, Tamilnadu (8.1782, 77.4326)... ✓ Roads:518 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Perambalur, Tamilnadu (11.2903, 78.9300)... ✓ Roads:27 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Salem, Tamilnadu (11.6470, 78.2107)... ✓ Roads:12 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sivagangai, Tamilnadu (9.9651, 78.7204)... ✓ Roads:6 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 62/109:
# Processing locations 306 to 310
#
#   Querying Trichy, Tamilnadu (10.8071, 78.6881)... ✓ Roads:618 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Theni, Tamilnadu (9.8693, 77.4223)... ✓ Roads:11 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tiruvannamalai, Tamilnadu (12.4289, 78.9992)... ✓ Roads:12 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tiruvarur, Tamilnadu (10.8621, 79.4790)... ✓ Roads:100 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Villupuram, Tamilnadu (11.9960, 79.7674)... ✓ Roads:60 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 63/109:
# Processing locations 311 to 315
#
#   Querying Tuticorin / Thoothukudi, Tamilnadu (8.8274, 78.1294)... ✓ Roads:270 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Adilabad, Telangana (19.6759, 78.5340)... ✓ Roads:745 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Hyderabad, Telangana (17.3850, 78.4867)... ✓ Roads:999 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Karimnagar, Telangana (18.4348, 79.1328)... ✓ Roads:751 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Khammam, Telangana (17.2465, 80.1500)... ✓ Roads:649 | Industrial:0 | Dumps:0 | Agriculture:4
#
# Batch completed. Waiting before next batch...
#
# Batch 64/109:
# Processing locations 316 to 320
#
#   Querying Kothur, Telangana (17.1486, 78.2887)... ✓ Roads:187 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nalgonda, Telangana (16.8580, 79.2175)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nizamabad, Telangana (18.6733, 78.0978)... ✓ Roads:701 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Patencheru, Telangana (17.5310, 78.2645)... ✓ Roads:515 | Industrial:5 | Dumps:0 | Agriculture:4
#   Querying Ramagundum, Telangana (18.7596, 79.4740)... ✓ Roads:229 | Industrial:2 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 65/109:
# Processing locations 321 to 325
#
#   Querying Sangareddy, Telangana (17.8684, 77.8227)... ✓ Roads:1 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Warangal, Telangana (17.9821, 79.5971)... ✓ Roads:699 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Agartala, Tripura (23.8312, 91.2824)... ✓ Roads:454 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Agra, Uttar Pradesh (27.1753, 78.0098)... ✓ Roads:580 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Aligarh, Uttar Pradesh (27.8761, 78.1358)... ✓ Roads:135 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 66/109:
# Processing locations 326 to 330
#
#   Querying Allahabad, Uttar Pradesh (25.4381, 81.8338)... ✓ Roads:736 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Anpara, Uttar Pradesh (24.2055, 82.7715)... ✓ Roads:146 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Ayodhya, Uttar Pradesh (26.7991, 82.2052)... ✓ Roads:398 | Industrial:0 | Dumps:0 | Agriculture:15
#   Querying Bagpat, Uttar Pradesh (28.9673, 77.6648)... ✓ Roads:349 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Bareily, Uttar Pradesh (28.3670, 79.4304)... ✓ Roads:528 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 67/109:
# Processing locations 331 to 335
#
#   Querying Bulandshahr, Uttar Pradesh (28.3874, 77.9744)... ✓ Roads:43 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Firozabad, Uttar Pradesh (27.1942, 78.4605)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gajroula, Uttar Pradesh (28.8446, 78.2396)... ✓ Roads:74 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Ghaziabad, Uttar Pradesh (28.7750, 77.4587)... ✓ Roads:60 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Gorakhpur, Uttar Pradesh (26.6678, 83.3642)... ✓ Roads:149 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 68/109:
# Processing locations 336 to 340
#
#   Querying Greater Noida, Uttar Pradesh (28.4671, 77.5138)... ✓ Roads:466 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Hapur, Uttar Pradesh (28.7167, 77.8904)... ✓ Roads:36 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jhansi, Uttar Pradesh (25.5299, 78.6528)... ✓ Roads:16 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kanpur, Uttar Pradesh (26.4609, 80.3218)... ✓ Roads:438 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Khurja, Uttar Pradesh (28.2063, 77.8764)... ✓ Roads:113 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 69/109:
# Processing locations 341 to 345
#
#   Querying Lucknow, Uttar Pradesh (26.8381, 80.9346)... ✓ Roads:781 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Mathura, Uttar Pradesh (27.4956, 77.6856)... ✓ Roads:559 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Meerut, Uttar Pradesh (29.0019, 77.7680)... ✓ Roads:317 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Moradabad, Uttar Pradesh (28.8797, 78.8095)... ✓ Roads:108 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Muzaffarnagar, Uttar Pradesh (29.4497, 77.7429)... ✓ Roads:336 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 70/109:
# Processing locations 346 to 350
#
#   Querying Noida, Uttar Pradesh (28.5706, 77.3272)... ✓ Roads:895 | Industrial:1 | Dumps:0 | Agriculture:3
#   Querying Saharanpur, Uttar Pradesh (29.9857, 77.5041)... ✓ Roads:89 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Unnao, Uttar Pradesh (26.5673, 80.6198)... ✓ Roads:26 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Varanasi, Uttar Pradesh (25.3356, 83.0076)... ✓ Roads:502 | Industrial:0 | Dumps:0 | Agriculture:3
#   Querying Dehradun, Uttarakhand (30.3256, 78.0437)... ✓ Roads:480 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 71/109:
# Processing locations 351 to 355
#
#   Querying Haldwani, Uttarakhand (29.2145, 79.5279)... ✓ Roads:1003 | Industrial:3 | Dumps:0 | Agriculture:11
#   Querying Haridwar, Uttarakhand (29.9384, 78.1453)... ✓ Roads:369 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Kashipur, Uttarakhand (29.2118, 78.9617)... ✓ Roads:823 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Rishikesh, Uttarakhand (30.1087, 78.2916)... ✓ Roads:442 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Rudrapur, Uttarakhand (28.9707, 79.3973)... ✓ Roads:765 | Industrial:4 | Dumps:0 | Agriculture:5
#
# Batch completed. Waiting before next batch...
#
# Batch 72/109:
# Processing locations 356 to 360
#
#   Querying Alipurduar, West Bengal (26.4852, 89.5247)... ✓ Roads:163 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Amtala, West Bengal (22.3669, 88.2777)... ✓ Roads:251 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Asansol, West Bengal (23.6871, 86.9747)... ✓ Roads:369 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Baharampur, West Bengal (24.1045, 88.2511)... ✓ Roads:349 | Industrial:0 | Dumps:0 | Agriculture:24
#   Querying Balurghat, West Bengal (25.2234, 88.7781)... ✓ Roads:410 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 73/109:
# Processing locations 361 to 365
#
#   Querying Bankura, West Bengal (23.1324, 87.2082)... ✓ Roads:67 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Barasat, West Bengal (22.7191, 88.4826)... ✓ Roads:713 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bardhaman, West Bengal (23.2496, 87.8682)... ✓ Roads:665 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Barrckpore, West Bengal (26.2303, 81.2330)... ✓ Roads:573 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Baruipur, West Bengal (22.3607, 88.4323)... ✓ Roads:420 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 74/109:
# Processing locations 366 to 370
#
#   Querying Bolpur, West Bengal (23.6612, 87.6962)... ✓ Roads:381 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chinsura, West Bengal (22.9024, 88.3893)... ✓ Roads:695 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Coochbihar, West Bengal (26.3257, 89.4511)... ✓ Roads:207 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dankuni, West Bengal (22.6821, 88.2907)... ✓ Roads:543 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Darjeeling, West Bengal (27.0378, 88.2632)... ✓ Roads:197 | Industrial:0 | Dumps:0 | Agriculture:65
#
# Batch completed. Waiting before next batch...
#
# Batch 75/109:
# Processing locations 371 to 375
#
#   Querying Durgapur, West Bengal (23.5350, 87.3380)... ✓ Roads:398 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Ghatal, West Bengal (22.6823, 87.6992)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Haldia, West Bengal (22.0281, 88.0633)... ✓ Roads:224 | Industrial:0 | Dumps:0 | Agriculture:11
#   Querying Howrah, West Bengal (22.5736, 88.3251)... ✓ Roads:658 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Jalpaiguri, West Bengal (26.6263, 88.7334)... ✓ Roads:25 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 76/109:
# Processing locations 376 to 380
#
#   Querying Jhargram, West Bengal (22.4539, 86.9949)... ✓ Roads:185 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kalimpong, West Bengal (27.0703, 88.4724)... ✓ Roads:115 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kalyani, West Bengal (22.9750, 88.4346)... ✓ Roads:358 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Kharagpur, West Bengal (22.3431, 87.3013)... ✓ Roads:318 | Industrial:1 | Dumps:0 | Agriculture:0
# ...
#   Querying Tirupur, Tamilnadu (11.1672, 77.3473)... ✓ Roads:278 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tuticorin, Tamilnadu (8.8053, 78.1453)... ✓ Roads:398 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Vellore, Tamilnadu (12.9022, 79.0611)... ✓ Roads:42 | Industrial:0 | Dumps:0 | Agriculture:12
#   Querying Hyderabad, Telangana (17.3606, 78.4741)... ✓ Roads:1003 | Industrial:0 | Dumps:0 | Agriculture:2
#
# Batch completed. Waiting before next batch...
#
# Batch 92/109:
# Processing locations 456 to 460
#
#   Querying Baghpat, Uttar Pradesh (29.0375, 77.3063)... ✓ Roads:22 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bareilly, Uttar Pradesh (28.4582, 79.4047)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Hatras, Uttar Pradesh (27.5958, 78.0524)... ✓ Roads:378 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Vrindavan, Uttar Pradesh (27.5754, 77.6938)... ✓ Roads:400 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Asansol+Raniganj, West Bengal (23.6739, 86.9524)... ✓ Roads:559 | Industrial:0 | Dumps:0 | Agriculture:1
#
# Batch completed. Waiting before next batch...
#
# Batch 93/109:
# Processing locations 461 to 465
#
#   Querying Barrckpore, West Bengal (22.7665, 88.3709)... ✓ Roads:887 | Industrial:19 | Dumps:0 | Agriculture:1
#   Querying Birpara, West Bengal (26.7113, 89.1390)... ✓ Roads:46 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Jaigaon, West Bengal (26.8549, 89.3767)... ✓ Roads:189 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Makhrapara /Alipurduar, West Bengal (26.3133, 89.4871)... ✓ Roads:42 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Uttarpara, West Bengal (22.6670, 88.3411)... ✓ Roads:697 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 94/109:
# Processing locations 466 to 470
#
#   Querying Port Blair, Andaman & Nicobar (UT) (11.6234, 92.7265)... ✓ Roads:245 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Anantapur, Andhra Pradesh (14.7242, 77.4307)... ✓ Roads:67 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Chittoor, Andhra Pradesh (13.2026, 79.0032)... ✓ Roads:5 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rajahmundry/ Rajamahendravaram, Andhra Pradesh (16.9966, 81.7726)... ✓ Roads:590 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Silcher, Assam (24.8330, 92.7789)... ✓ Roads:248 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 95/109:
# Processing locations 471 to 475
#
#   Querying Chhal, Chattisgarh (22.0966, 83.1119)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kunjemura, Chattisgarh (21.9587, 83.6635)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Milupara, Chattisgarh (21.9041, 83.6582)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tumidh, Chattisgarh (21.7612, 83.4108)... ✓ Roads:14 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Sonipat, Haryana (28.9954, 77.0234)... ✓ Roads:873 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 96/109:
# Processing locations 476 to 480
#
#   Querying Vashisht, Himachal Pradesh (32.2669, 77.1876)... ✓ Roads:190 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ramban (J), Jammu & Kashmir (UT) (33.2346, 75.2376)... ✓ Roads:29 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Ahmednagar, Maharashtra (19.1628, 74.8580)... ✓ Roads:16 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Amravati, Maharashtra (20.9320, 77.7523)... ✓ Roads:870 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Aurangabad, Maharashtra (19.8758, 75.3393)... ✓ Roads:850 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 97/109:
# Processing locations 481 to 485
#
#   Querying Badlapur, Maharashtra (19.1668, 73.2368)... ✓ Roads:498 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Belapur, Maharashtra (19.0222, 73.0390)... ✓ Roads:759 | Industrial:8 | Dumps:0 | Agriculture:5
#   Querying Bhiwandi, Maharashtra (19.2967, 73.0631)... ✓ Roads:443 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Boisar, Maharashtra (19.8036, 72.7559)... ✓ Roads:174 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Chandrapur, Maharashtra (19.9500, 79.3000)... ✓ Roads:446 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 98/109:
# Processing locations 486 to 490
#
#   Querying Dhule, Maharashtra (20.9013, 74.7774)... ✓ Roads:484 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dombivali / Kalyan, Maharashtra (19.2183, 73.0864)... ✓ Roads:654 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Jalgaon, Maharashtra (21.0107, 75.5684)... ✓ Roads:453 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jalna, Maharashtra (19.8410, 75.8866)... ✓ Roads:541 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Kolhapur, Maharashtra (16.7050, 74.2433)... ✓ Roads:576 | Industrial:3 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 99/109:
# Processing locations 491 to 495
#
#   Querying Latur, Maharashtra (18.4000, 76.5833)... ✓ Roads:747 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mahad, Maharashtra (18.0833, 73.4167)... ✓ Roads:67 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Malegao, Maharashtra (20.5537, 74.5288)... ✓ Roads:792 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Mira Bhayander, Maharashtra (19.2952, 72.8544)... ✓ Roads:527 | Industrial:3 | Dumps:0 | Agriculture:9
#   Querying Mumbai, Maharashtra (19.0760, 72.8777)... ✓ Roads:658 | Industrial:6 | Dumps:0 | Agriculture:12
#
# Batch completed. Waiting before next batch...
#
# Batch 100/109:
# Processing locations 496 to 500
#
#   Querying Nagpur, Maharashtra (21.1458, 79.0882)... ✓ Roads:624 | Industrial:4 | Dumps:0 | Agriculture:1
#   Querying Nanded, Maharashtra (19.1383, 77.3210)... ✓ Roads:300 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Nashik, Maharashtra (19.9975, 73.7898)... ✓ Roads:569 | Industrial:2 | Dumps:0 | Agriculture:12
#   Querying Navi Mumbai, Maharashtra (19.0330, 73.0297)... ✓ Roads:633 | Industrial:4 | Dumps:0 | Agriculture:10
#   Querying Parbhani, Maharashtra (19.2700, 76.7600)... ✓ Roads:637 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 101/109:
# Processing locations 501 to 505
#
#   Querying Pimpri Chinchwad, Maharashtra (18.6279, 73.8007)... ✓ Roads:823 | Industrial:5 | Dumps:0 | Agriculture:0
#   Querying Pune, Maharashtra (18.5204, 73.8567)... ✓ Roads:1318 | Industrial:0 | Dumps:0 | Agriculture:9
#   Querying Roha, Maharashtra (18.4408, 73.1190)... ✓ Roads:51 | Industrial:2 | Dumps:0 | Agriculture:0
#   Querying Sangli, Maharashtra (16.8524, 74.5815)... ✓ Roads:497 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Solapur, Maharashtra (17.6599, 75.9064)... ✓ Roads:446 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 102/109:
# Processing locations 506 to 510
#
#   Querying Tarapur, Maharashtra (19.8667, 72.7000)... ✓ Roads:3 | Industrial:0 | Dumps:0 | Agriculture:1
#   Querying Thane, Maharashtra (19.2183, 72.9781)... ✓ Roads:804 | Industrial:4 | Dumps:0 | Agriculture:3
#   Querying Ulhas Nagar, Maharashtra (19.2167, 73.1500)... ✓ Roads:0 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Vasai virar, Maharashtra (19.3850, 72.8295)... ✓ Roads:318 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Imphal, Manipur (24.8170, 93.9368)... ✓ Roads:299 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 103/109:
# Processing locations 511 to 515
#
#   Querying Dawki, Meghalaya (25.2029, 92.0344)... ✓ Roads:7 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Nongstoin, Meghalaya (25.5170, 91.2666)... ✓ Roads:42 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Shillong, Meghalaya (25.5788, 91.8933)... ✓ Roads:476 | Industrial:0 | Dumps:0 | Agriculture:18
#   Querying Tura, Meghalaya (25.5142, 90.2026)... ✓ Roads:11 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Umsning, Meghalaya (25.8227, 91.8694)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 104/109:
# Processing locations 516 to 520
#
#   Querying Aizwal, Mizoram (23.7271, 92.7176)... ✓ Roads:350 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Champhai, Mizoram (23.4560, 93.3291)... ✓ Roads:11 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Kolasib, Mizoram (24.2240, 92.6787)... ✓ Roads:58 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Lawngtlai, Mizoram (22.5411, 92.8926)... ✓ Roads:47 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Lunglei, Mizoram (22.8660, 92.7330)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 105/109:
# Processing locations 521 to 525
#
#   Querying Mamit, Mizoram (23.9292, 92.4900)... ✓ Roads:2 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Siaha, Mizoram (22.4837, 92.9745)... ✓ Roads:115 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Serchhip, Mizoram (23.2980, 92.8460)... ✓ Roads:29 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Dimapur, Nagaland (25.9091, 93.7260)... ✓ Roads:359 | Industrial:3 | Dumps:0 | Agriculture:0
#   Querying Kohima, Nagaland (25.6747, 94.1100)... ✓ Roads:195 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 106/109:
# Processing locations 526 to 530
#
#   Querying Angul, Odisha (20.8410, 85.0970)... ✓ Roads:210 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Balasore, Odisha (21.4942, 86.9316)... ✓ Roads:251 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Baripada, Odisha (21.9407, 86.7198)... ✓ Roads:90 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Bhubaneshwar, Odisha (20.2961, 85.8245)... ✓ Roads:501 | Industrial:0 | Dumps:0 | Agriculture:2
#   Querying Bileipada, Odisha (22.0900, 85.3300)... ✓ Roads:11 | Industrial:1 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 107/109:
# Processing locations 531 to 535
#
#   Querying Brajrajnagar, Odisha (21.8200, 83.9200)... ✓ Roads:53 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Cuttack, Odisha (20.4625, 85.8828)... ✓ Roads:420 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Jharsuguda, Odisha (21.8553, 84.0060)... ✓ Roads:63 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Keonjhar, Odisha (21.6333, 85.5833)... ✓ Roads:59 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Konark, Odisha (19.8974, 86.1140)... ✓ Roads:34 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 108/109:
# Processing locations 536 to 540
#
#   Querying Nayagarh, Odisha (20.1280, 85.0961)... ✓ Roads:35 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Paradeep, Odisha (20.3167, 86.6167)... ✓ Roads:22 | Industrial:1 | Dumps:0 | Agriculture:0
#   Querying Puri, Odisha (19.8135, 85.8312)... ✓ Roads:374 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rairangpur, Odisha (22.2780, 86.1847)... ✓ Roads:6 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Rourkela, Odisha (22.2604, 84.8536)... ✓ Roads:368 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
# Batch 109/109:
# Processing locations 541 to 544
#
#   Querying Sambalpur, Odisha (21.4700, 83.9701)... ✓ Roads:494 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Suakati, Odisha (21.6367, 85.5775)... ✓ Roads:32 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Talcher, Odisha (20.9483, 85.2332)... ✓ Roads:38 | Industrial:0 | Dumps:0 | Agriculture:0
#   Querying Tensa, Odisha (21.8728, 85.1713)... ✓ Roads:48 | Industrial:0 | Dumps:0 | Agriculture:0
#
# Batch completed. Waiting before next batch...
#
#
# ================================================================================
# EXTRACTION SUMMARY
# ================================================================================
#
# Total locations processed: 544
# Successful queries: 544/544
#
#                                Feature Statistics
# --------------------------------------------------------------------------------
# Feature              Total        Mean         Max
# --------------------------------------------------------------------------------
# Roads                158814       291.9        2459
# Industrial           414          0.8          19
# Dump Sites           9            0.0          2
# Agriculture          809          1.5          73
# --------------------------------------------------------------------------------
#
# Merging extracted features with original air quality data...
#
# Saving merged data to Air_Quality_with_OSM_Features.xlsx...
# ✓ Successfully saved to Air_Quality_with_OSM_Features.xlsx
#
#                       Sample Results (First 15 locations):
#    City / town / village State / Union Territory  Roads_count  \
# 0              Amaravati          Andhra Pradesh           84
# 1               Anatapur          Andhra Pradesh          723
# 2                Chittor          Andhra Pradesh          369
# 3                  Eluru          Andhra Pradesh          671
# 4                 Guntur          Andhra Pradesh          780
# 5                 Kadapa          Andhra Pradesh          588
# 6               Kakinada          Andhra Pradesh          419
# 7                Kurnool          Andhra Pradesh          679
# 8                Nellore          Andhra Pradesh          697
# 9                 Ongole          Andhra Pradesh          536
# 10           Rajahmundry          Andhra Pradesh          841
# 11            Srikakulam          Andhra Pradesh          468
# 12              Tirupati          Andhra Pradesh          737
# 13            Vijayawada          Andhra Pradesh          576
# 14         Visakhapatnam          Andhra Pradesh          253
#
#     Industrial_zones_count  Dump_sites_count  Agricultural_fields_count  \
# 0                        0                 0                          2
# 1                        1                 0                          0
# 2                        1                 0                          0
# 3                        0                 0                          0
# 4                        2                 0                          0
# 5                        1                 0                          0
# 6                        4                 0                          0
# 7                        0                 0                          3
# 8                        1                 0                          0
# 9                        1                 0                          0
# 10                       1                 0                          2
# 11                       0                 0                          3
# 12                       1                 0                          3
# 13                       3                 0                          0
# 14                       9                 0                          0
#
#     Pollution_source_risk  Green_area_ratio
# 0                    0.25              0.02
# 1                    2.17              0.00
# 2                    1.11              0.00
# 3                    2.01              0.00
# 4                    2.35              0.00
# 5                    1.77              0.00
# 6                    1.27              0.00
# 7                    2.04              0.00
# 8                    2.10              0.00
# 9                    1.61              0.00
# 10                   2.53              0.00
# 11                   1.40              0.01
# 12                   2.22              0.00
# 13                   1.74              0.00
# 14                   0.79              0.00
#
# ================================================================================
# ✓ Processing Complete!
# ================================================================================
